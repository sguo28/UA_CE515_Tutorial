# %% [markdown]
# ### GTFS (General Transit Feed Specification)
# * A standard format for public transportation schedules and associated geographic information.
# * It is defined by the [Google Transit Feed Specification](https://developers.google.com/transit/gtfs/reference/).
# * GTFS includes a set of files that describe the routes, stops, and schedules for a transit agency's services, as well as information about fares and geographic information (such as the location of stops and routes).

# %% [markdown]
# ### Before we start
# #### install the following packages
#
# * pip install gtfs-kit
# (Source: https://pypi.org/project/gtfs-kit/)
# * conda install -c conda-forge shapely
# * conda install -c conda-forge geopandas
# * conda install -c conda-forge pandas

# %%
# first load the packages we need
import gtfs_kit as gk
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import warnings
from shapely.errors import ShapelyDeprecationWarning
warnings.simplefilter("ignore", ShapelyDeprecationWarning)

# warnings.filterwarnings("ignore")
# warnings.simplefilter("ignore", ShapelyDeprecationWarning)

# %%
# feed contains all the information in the GTFS feed
feed = (gk.read_feed('data/gtfs_data/crimson_ride_sample.zip', dist_units='mi'))

# %%
# let's look at the routes and trips
routes = gpd.GeoDataFrame.from_features(feed.routes_to_geojson())
trips = gpd.GeoDataFrame.from_features(feed.trips_to_geojson())
stops = gpd.GeoDataFrame.from_features(feed.stops_to_geojson())

# %%
feed.stop_times
# Out:
#     trip_id arrival_time departure_time stop_id  stop_sequence
# 0    228040     06:50:00       06:50:00    7686              1
# 1    228040     06:52:00       06:52:00   24483              2
# 2    228040     06:55:00       06:55:00    5102              3
# 3    228040     06:59:00       06:59:00    7713              4
# 4    228040     07:00:00       07:00:00    7637              5
# ..      ...          ...            ...     ...            ...
# 403  228141     20:55:00       20:55:00    7713              4
# 404  228141     20:56:00       20:56:00    7637              5
# 405  228141     20:57:00       20:57:00    7635              6
# 406  228141     20:58:00       20:58:00    7715              7
# 407  228141     21:00:00       21:00:00    7633              8
#
# [408 rows x 5 columns]

# %%
feed.stops
# Out:
#   stop_id stop_code                                 stop_name stop_desc  \
# 0    7686      3130                                   Bus Hub       NaN
# 1    7635      3008  Capstone Retirement Village (Northbound)       NaN
# 2    7637      3009                  Child Development Center       NaN
# 3   24483     24483                      Gayle-Gorgas Library       NaN
# 4    7633      3051                            North Commuter       NaN
# 5    5102      3029                      Rose Admin. Building       NaN
# 6    7713      3043                    Soccer Lot (Eastbound)       NaN
# 7    7715      3052                    Upper Rec (Northbound)       NaN
#
#     stop_lat   stop_lon stop_url  location_type stop_timezone  \
# 0  33.212909 -87.541564      NaN              0           NaN
# 1  33.210385 -87.529519      NaN              0           NaN
# 2  33.208850 -87.529617      NaN              0           NaN
# 3  33.212032 -87.546073      NaN              0           NaN
# 4  33.213598 -87.533746      NaN              0           NaN
# 5  33.209650 -87.546967      NaN              0           NaN
# 6  33.208317 -87.534167      NaN              0           NaN
# 7  33.212467 -87.530270      NaN              0           NaN
#
#    wheelchair_boarding  platform_code
# 0                    0            NaN
# 1                    0            NaN
# 2                    0            NaN
# 3                    0            NaN
# 4                    0            NaN
# 5                    0            NaN
# 6                    0            NaN
# 7                    0            NaN

# %%
# explore routes, trips, and stops.

# %%
# plot routes to a map
feed.map_stops(feed.stops.stop_id[:])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2018acde546c79b32b3e840cd9756b9b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2018acde546c79b32b3e840cd9756b9b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2018acde546c79b32b3e840cd9756b9b = L.map(
#                 &quot;map_2018acde546c79b32b3e840cd9756b9b&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d35936ac266460d95e364aafe08dd1b5 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2018acde546c79b32b3e840cd9756b9b);
#
#
#             var fast_marker_cluster_cffd9afa822ae360b096acbe23ec0091 = (function(){
#                 var callback =     function (row) {
#         var imarker;
#         marker = L.circleMarker(new L.LatLng(row[0], row[1]),
#             {&#x27;radius&#x27;: 8, &#x27;fill&#x27;: &#x27;true&#x27;, &#x27;color&#x27;: &#x27;#fc8d62&#x27;, &#x27;weight&#x27;: 1, &#x27;fillOpacity&#x27;: 0.75}
#         );
#         marker.bindPopup(
#             &#x27;&lt;b&gt;Stop name&lt;/b&gt;: &#x27; + row[2] + &#x27;&lt;br&gt;&#x27; +
#             &#x27;&lt;b&gt;Stop code&lt;/b&gt;: &#x27; + row[3] + &#x27;&lt;br&gt;&#x27; +
#             &#x27;&lt;b&gt;Stop ID&lt;/b&gt;: &#x27; + row[4]
#         );
#         return marker;
#     };
#     ;
#
#                 var data = [[33.212909, -87.541564, &quot;Bus Hub&quot;, &quot;3130&quot;, &quot;7686&quot;], [33.2103848, -87.5295192, &quot;Capstone Retirement Village (Northbound)&quot;, &quot;3008&quot;, &quot;7635&quot;], [33.20885, -87.52961667, &quot;Child Development Center&quot;, &quot;3009&quot;, &quot;7637&quot;], [33.212031533, -87.546073196, &quot;Gayle-Gorgas Library&quot;, &quot;24483&quot;, &quot;24483&quot;], [33.2135984, -87.5337463, &quot;North Commuter&quot;, &quot;3051&quot;, &quot;7633&quot;], [33.20965, -87.54696667, &quot;Rose Admin. Building&quot;, &quot;3029&quot;, &quot;5102&quot;], [33.2083166, -87.5341666, &quot;Soccer Lot (Eastbound)&quot;, &quot;3043&quot;, &quot;7713&quot;], [33.2124674, -87.5302702, &quot;Upper Rec (Northbound)&quot;, &quot;3052&quot;, &quot;7715&quot;]];
#                 var cluster = L.markerClusterGroup({&quot;disableClusteringAtZoom&quot;: 14});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_2018acde546c79b32b3e840cd9756b9b);
#                 return cluster;
#             })();
#
#
#             map_2018acde546c79b32b3e840cd9756b9b.fitBounds(
#                 [[33.2083166, -87.54696667], [33.2135984, -87.5295192]],
#                 {&quot;padding&quot;: [1, 1]}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# plot routes to a map
feed.map_routes(feed.routes.route_id[:],include_stops=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_032473eb93bb9ec7cb7850d8f318eb7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_032473eb93bb9ec7cb7850d8f318eb7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_032473eb93bb9ec7cb7850d8f318eb7f = L.map(
#                 &quot;map_032473eb93bb9ec7cb7850d8f318eb7f&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_661b6d5fea76813068d485d0d9d9bfbe = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_032473eb93bb9ec7cb7850d8f318eb7f);
#
#
#             var feature_group_6cae659cc21d37a2a67c85838fb5f960 = L.featureGroup(
#                 {}
#             ).addTo(map_032473eb93bb9ec7cb7850d8f318eb7f);
#
#
#         function geo_json_79e5235a03fa34964d66053d991f15c6_styler(feature) {
#             switch(feature.properties.route_id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#66c2a5&quot;};
#             }
#         }
#
#         function geo_json_79e5235a03fa34964d66053d991f15c6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_79e5235a03fa34964d66053d991f15c6 = L.geoJson(null, {
#                 onEachFeature: geo_json_79e5235a03fa34964d66053d991f15c6_onEachFeature,
#
#                 style: geo_json_79e5235a03fa34964d66053d991f15c6_styler,
#         });
#
#         function geo_json_79e5235a03fa34964d66053d991f15c6_add (data) {
#             geo_json_79e5235a03fa34964d66053d991f15c6
#                 .addData(data)
#                 .addTo(feature_group_6cae659cc21d37a2a67c85838fb5f960);
#         }
#             geo_json_79e5235a03fa34964d66053d991f15c6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-87.54159, 33.21287], [-87.54152, 33.21299], [-87.54147, 33.21308], [-87.54147, 33.21317], [-87.54149, 33.2132], [-87.54155, 33.21329], [-87.54179, 33.21317], [-87.5421, 33.21302], [-87.54251, 33.21276], [-87.54274, 33.21256], [-87.54279, 33.21251], [-87.54305, 33.21259], [-87.54313, 33.21259], [-87.54322, 33.21258], [-87.54337, 33.21255], [-87.54351, 33.2125], [-87.54383, 33.21236], [-87.54391, 33.21232], [-87.54401, 33.21226], [-87.54408, 33.21221], [-87.54414, 33.21216], [-87.54417, 33.21211], [-87.544237551, 33.211973071], [-87.544255775, 33.211861224], [-87.546333936, 33.212117404], [-87.547612449, 33.212274095], [-87.547993528, 33.210881012], [-87.548310233, 33.209882873], [-87.547158572, 33.209705117], [-87.546963382, 33.209667756], [-87.544398542, 33.209214094], [-87.540561953, 33.208535314], [-87.53723, 33.207964291], [-87.537016093, 33.208896732], [-87.535875102, 33.208711418], [-87.535534432, 33.208627361], [-87.53535, 33.20857], [-87.53509, 33.20849], [-87.53479, 33.20843], [-87.53453, 33.20841], [-87.534172682, 33.20841693], [-87.533742682, 33.208458977], [-87.53351793, 33.208502756], [-87.533208513, 33.208599605], [-87.532750029, 33.208832836], [-87.532572157, 33.208905117], [-87.532351079, 33.208965512], [-87.53213, 33.20899], [-87.531328572, 33.208992047], [-87.531016852, 33.208974094], [-87.530752974, 33.208919408], [-87.530542216, 33.208823896], [-87.530416064, 33.208778779], [-87.529688047, 33.20869307], [-87.52964, 33.20891], [-87.529558775, 33.209381023], [-87.529531458, 33.209805512], [-87.529566093, 33.21038248], [-87.529639737, 33.21084378], [-87.52972, 33.21118], [-87.529908047, 33.21161], [-87.530332915, 33.212446732], [-87.530572187, 33.21289878], [-87.531284898, 33.214409172], [-87.53172, 33.21425], [-87.53277, 33.21388], [-87.53353, 33.21361], [-87.53372, 33.21354], [-87.53469, 33.21319], [-87.53473, 33.21318], [-87.53515, 33.21304], [-87.53578, 33.21282], [-87.53653, 33.21262], [-87.53756, 33.21248], [-87.53786, 33.21248], [-87.53826, 33.21249], [-87.5389, 33.21256], [-87.53928, 33.21263], [-87.53976, 33.21276], [-87.54043, 33.21302], [-87.54074, 33.21316], [-87.54098, 33.21327], [-87.54116, 33.21348], [-87.54123, 33.21344], [-87.54133, 33.2134], [-87.54148, 33.21332], [-87.54155, 33.21329], [-87.5421, 33.21302], [-87.54191, 33.21285], [-87.54185, 33.21273], [-87.54177, 33.21276], [-87.54173, 33.21278], [-87.54159, 33.21287], [-87.54155, 33.21294]], &quot;type&quot;: &quot;LineString&quot;}, &quot;properties&quot;: {&quot;agency_id&quot;: &quot;240&quot;, &quot;color&quot;: &quot;#66c2a5&quot;, &quot;route_color&quot;: &quot;F5AE07&quot;, &quot;route_id&quot;: &quot;17337&quot;, &quot;route_long_name&quot;: &quot;HUB 1 Route&quot;, &quot;route_short_name&qu

# %%
# mannually plot it to a map (using maplotlib, geopandas, contextily)

import contextily as ctx
# conda install -c conda-forge contextily=1.1.0

fig, axe = plt.subplots(nrows=1, ncols=1, figsize=(8.7, 8.7)) # set up a blank figure

ax = routes.plot(alpha=0.5, linewidth=3, color = [f"#{i}" for i in routes["route_color"]], zorder=1, ax=axe) # plot the routes

# ctx.add_basemap(ax, zoom=14, source = ctx.sources.ST_TONER_LITE, alpha=0.5, crs = "EPSG:4326") # add a basemap

stops.plot(ax=axe,markersize =50,color = "red",zorder=2, alpha=0.5) # plot the stops

# # set up the lon-lat range of the coverage area
maxlat,maxlon = 33.22934, -87.52
minlat,minlon = 33.195, -87.55292

# # set the axis limits
ax.set_xlim(minlon,maxlon)
ax.set_ylim(minlat,maxlat)

plt.tight_layout()
# plt.savefig("map.png", dpi=300) # save the figure
plt.show()

# %%
# get the sample trajectory data covered by one bus.
sp = pd.read_json("data/sample_traj.json")

# %%
sp
# Out:
#                 id  userId   bus  route   latitude  longitude      speed  \
# 157353  6923106528     240  7027  Hub 1  33.213259 -87.518882   8.120092
# 157368  6923107115     240  7027  Hub 1  33.213334 -87.519101  10.983375
# 157386  6923107700     240  7027  Hub 1  33.213385 -87.519321   7.829290
# 157400  6923108467     240  7027  Hub 1  33.213527 -87.519544  12.795297
# 157419  6923109177     240  7027  Hub 1  33.213644 -87.519761   5.950260
# ...            ...     ...   ...    ...        ...        ...        ...
# 166707  6923475939     240  7027  Hub 1  33.212621 -87.543148  14.092722
# 166715  6923476283     240  7027  Hub 1  33.212580 -87.543381  16.642834
# 166727  6923476582     240  7027  Hub 1  33.212491 -87.543611  18.633710
# 166742  6923477090     240  7027  Hub 1  33.212336 -87.543940  16.709942
# 166752  6923477527     240  7027  Hub 1  33.212195 -87.544157  10.737312
#
#         course  heading              created            datetime  invalid  \
# 157353     305      NaN  2022-04-01 17:08:21 2022-04-01 17:08:21        0
# 157368     285      NaN  2022-04-01 17:08:26 2022-04-01 17:08:26        0
# 157386     299      NaN  2022-04-01 17:08:31 2022-04-01 17:08:31        0
# 157400     308      NaN  2022-04-01 17:08:36 2022-04-01 17:08:37        0
# 157419     303      NaN  2022-04-01 17:08:42 2022-04-01 17:08:43        0
# ...        ...      ...                  ...                 ...      ...
# 166707     274      NaN  2022-04-01 17:59:41 2022-04-01 17:59:41        0
# 166715     251      NaN  2022-04-01 17:59:44 2022-04-01 17:59:44        0
# 166727     243      NaN  2022-04-01 17:59:47 2022-04-01 17:59:47        0
# 166742     238      NaN  2022-04-01 17:59:51 2022-04-01 17:59:51        0
# 166752     222      NaN  2022-04-01 17:59:55 2022-04-01 17:59:55        0
#
#         correctedLatitude  correctedLongitude  calculatedCourse  paxLoad  \
# 157353          33.210844          -87.529640        318.346318        1
# 157368          33.210844          -87.529640        288.874349        1
# 157386          33.210917          -87.529657        282.935719        1
# 157400          33.211102          -87.529701        302.582692        1
# 157419          33.211180          -87.529720        298.412327        1
# ...                   ...                 ...               ...      ...
# 166707          33.212588          -87.543144        277.193826        1
# 166715          33.212550          -87.543370        260.056479        1
# 166727          33.212461          -87.543598        248.914158        1
# 166742          33.212311          -87.543925        244.773721        1
# 166752          33.212166          -87.544133        236.880601        1
#
#                                                      more  deviceId  busId  \
# 157353  {"eventCode":101,"hdop":8,"rssi":-107,"satelli...    401218   2823
# 157368  {"eventCode":102,"hdop":9,"rssi":-107,"satelli...    401218   2823
# 157386  {"eventCode":102,"hdop":9,"rssi":-107,"satelli...    401218   2823
# 157400  {"eventCode":102,"hdop":9,"rssi":-104,"satelli...    401218   2823
# 157419  {"eventCode":102,"hdop":10,"rssi":-104,"satell...    401218   2823
# ...                                                   ...       ...    ...
# 166707  {"eventCode":34,"hdop":11,"rssi":-82,"satellit...    401218   2823
# 166715  {"eventCode":102,"hdop":9,"rssi":-82,"satellit...    401218   2823
# 166727  {"eventCode":33,"hdop":9,"rssi":-82,"satellite...    401218   2823
# 166742  {"eventCode":102,"hdop":9,"rssi":-82,"satellit...    401218   2823
# 166752  {"eventCode":102,"hdop":9,"rssi":-82,"satellit...    401218   2823
#
#         routeBlockId  routeStopId  trip  tripId  timePoint  timePointId  \
# 157353         43608       512616   NaN  228076        NaN      4170541
# 157368         43608       512616   NaN  228076        NaN      4170541
# 157386         43608       512616   NaN  228076        NaN      4170541
# 157400         43608       512616   NaN  228076        NaN      4170541
# 157419         43608       512616   NaN  228076        NaN      4170541
# ...              ...          ...   ...     ...        ...          ...
# 166707         43608       512614   NaN  228079        NaN      4170563
# 166715         43608       512614   NaN  228079        NaN      4170563
# 166727         43608       512614   NaN  228079        NaN      4170563
# 166742         43608       512614   NaN  228079        NaN      4170563
# 166752         43608       512614   NaN  228079        NaN      4170563
#
#         manual  accuracy  provider      device routeBlock  outOfService  \
# 157353     NaN       NaN       NaN  5571009278      Hub 1             0
# 157368     NaN       NaN       NaN  5571009278      Hub 1             0
# 157386     NaN       NaN       NaN  5571009278      Hub 1             0
# 157400     NaN       NaN       NaN  5571009278      Hub 1             0
# 157419     NaN       NaN       NaN  5571009278      Hub 1             0
# ...        ...       ...       ...         ...        ...           ...
# 166707     NaN       NaN       NaN  5571009278      Hub 1             0
# 166715     NaN       NaN       NaN  5571009278      Hub 1             0
# 166727     NaN       NaN       NaN  5571009278      Hub 1             0
# 166742     NaN       NaN       NaN  5571009278      Hub 1             0
# 166752     NaN       NaN       NaN  5571009278      Hub 1             0
#
#           driver  driverId                  stop  stopId  point  day  hour  \
# 157353  Sidney S      3940  Rose Admin. Building    5102    NaN    1    17
# 157368  Sidney S      3940  Rose Admin. Building    5102    NaN    1    17
# 157386  Sidney S      3940  Rose Admin. Building    5102    NaN    1    17
# 157400  Sidney S      3940  Rose Admin. Building    5102    NaN    1    17
# 157419  Sidney S      3940  Rose Admin. Building    5102    NaN    1    17
# ...          ...       ...                   ...     ...    ...  ...   ...
# 166707  Sidney S      3940               Bus Hub    7686    NaN    1    17
# 166715  Sidney S      3940               Bus Hub    7686    NaN    1    17
# 166727  Sidney S      3940               Bus Hub    7686    NaN    1    17
# 166742  Sidney S      3940               Bus Hub    7686    NaN    1    17
# 166752  Sidney S      3940               Bus Hub    7686    NaN    1    17
#
#         acceleration   mass         a  theta         v          P_w  eta_RB_t
# 157353           NaN  15731       NaN      0  3.629903          NaN         0
# 157368      0.255993  15731  0.255993      0  4.909868  5653.982207         0
# 157386     -0.281992  15731 -0.281992      0  3.499906 -2850.522773         0
# 157400      0.369990  15731  0.369990      0  5.719847  7477.368307         0
# 157419     -0.509986  15731 -0.509986      0  2.659929 -6455.183429         0
# ...              ...    ...       ...    ...       ...          ...       ...
# 166707      0.359990  15731  0.359990      0  6.299831  7344.434100         0
# 166715      0.379990  15731  0.379990      0  7.439800  7713.803045         0
# 166727      0.296659  15731  0.296659      0  8.329777  6451.986653         0
# 166742     -0.214994  15731 -0.214994      0  7.469800 -1644.327218         0
# 166752     -0.667482  15731 -0.667482      0  4.799871 -8876.940543         0
#
# [535 rows x 45 columns]

# %%
sp.plot.scatter("longitude","latitude")
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
sp.columns
# Out:
# Index(['id', 'userId', 'bus', 'route', 'latitude', 'longitude', 'speed',
#        'course', 'heading', 'created', 'datetime', 'invalid',
#        'correctedLatitude', 'correctedLongitude', 'calculatedCourse',
#        'paxLoad', 'more', 'deviceId', 'busId', 'routeBlockId', 'routeStopId',
#        'trip', 'tripId', 'timePoint', 'timePointId', 'manual', 'accuracy',
#        'provider', 'device', 'routeBlock', 'outOfService', 'driver',
#        'driverId', 'stop', 'stopId', 'point', 'day', 'hour', 'acceleration',
#        'mass', 'a', 'theta', 'v', 'P_w', 'eta_RB_t'],
#       dtype='object')

# %%
# let's look at the data
sp.head(5)
# Out:
#                 id  userId   bus  route   latitude  longitude      speed  \
# 157353  6923106528     240  7027  Hub 1  33.213259 -87.518882   8.120092
# 157368  6923107115     240  7027  Hub 1  33.213334 -87.519101  10.983375
# 157386  6923107700     240  7027  Hub 1  33.213385 -87.519321   7.829290
# 157400  6923108467     240  7027  Hub 1  33.213527 -87.519544  12.795297
# 157419  6923109177     240  7027  Hub 1  33.213644 -87.519761   5.950260
#
#         course  heading              created            datetime  invalid  \
# 157353     305      NaN  2022-04-01 17:08:21 2022-04-01 17:08:21        0
# 157368     285      NaN  2022-04-01 17:08:26 2022-04-01 17:08:26        0
# 157386     299      NaN  2022-04-01 17:08:31 2022-04-01 17:08:31        0
# 157400     308      NaN  2022-04-01 17:08:36 2022-04-01 17:08:37        0
# 157419     303      NaN  2022-04-01 17:08:42 2022-04-01 17:08:43        0
#
#         correctedLatitude  correctedLongitude  calculatedCourse  paxLoad  \
# 157353          33.210844          -87.529640        318.346318        1
# 157368          33.210844          -87.529640        288.874349        1
# 157386          33.210917          -87.529657        282.935719        1
# 157400          33.211102          -87.529701        302.582692        1
# 157419          33.211180          -87.529720        298.412327        1
#
#                                                      more  deviceId  busId  \
# 157353  {"eventCode":101,"hdop":8,"rssi":-107,"satelli...    401218   2823
# 157368  {"eventCode":102,"hdop":9,"rssi":-107,"satelli...    401218   2823
# 157386  {"eventCode":102,"hdop":9,"rssi":-107,"satelli...    401218   2823
# 157400  {"eventCode":102,"hdop":9,"rssi":-104,"satelli...    401218   2823
# 157419  {"eventCode":102,"hdop":10,"rssi":-104,"satell...    401218   2823
#
#         routeBlockId  routeStopId  trip  tripId  timePoint  timePointId  \
# 157353         43608       512616   NaN  228076        NaN      4170541
# 157368         43608       512616   NaN  228076        NaN      4170541
# 157386         43608       512616   NaN  228076        NaN      4170541
# 157400         43608       512616   NaN  228076        NaN      4170541
# 157419         43608       512616   NaN  228076        NaN      4170541
#
#         manual  accuracy  provider      device routeBlock  outOfService  \
# 157353     NaN       NaN       NaN  5571009278      Hub 1             0
# 157368     NaN       NaN       NaN  5571009278      Hub 1             0
# 157386     NaN       NaN       NaN  5571009278      Hub 1             0
# 157400     NaN       NaN       NaN  5571009278      Hub 1             0
# 157419     NaN       NaN       NaN  5571009278      Hub 1             0
#
#           driver  driverId                  stop  stopId  point  day  hour  \
# 157353  Sidney S      3940  Rose Admin. Building    5102    NaN    1    17
# 157368  Sidney S      3940  Rose Admin. Building    5102    NaN    1    17
# 157386  Sidney S      3940  Rose Admin. Building    5102    NaN    1    17
# 157400  Sidney S      3940  Rose Admin. Building    5102    NaN    1    17
# 157419  Sidney S      3940  Rose Admin. Building    5102    NaN    1    17
#
#         acceleration   mass         a  theta         v          P_w  eta_RB_t
# 157353           NaN  15731       NaN      0  3.629903          NaN         0
# 157368      0.255993  15731  0.255993      0  4.909868  5653.982207         0
# 157386     -0.281992  15731 -0.281992      0  3.499906 -2850.522773         0
# 157400      0.369990  15731  0.369990      0  5.719847  7477.368307         0
# 157419     -0.509986  15731 -0.509986      0  2.659929 -6455.183429         0

# %%
for trip_id, sp_ in sp.groupby("tripId"):
    sp_.plot.scatter("correctedLongitude", "correctedLatitude",title= f"Trip ID: {trip_id}", c ="r")

# %%
fig, ax = plt.subplots(figsize=(6,2.5)) # set up blank figure

# %%
# viz the route, together with the stops and the trajectory

fig, ax = plt.subplots(figsize=(6*2,2.5*2)) # set up blank figure

sp.plot(x="correctedLongitude",y="correctedLatitude",kind="scatter",s=1.0, c="speed", cmap="RdYlGn", ax=ax) # one driver for one day.


sp.head(1).plot(x="correctedLongitude",y="correctedLatitude",kind="scatter", label="start", ax=ax, marker="o", color="r",s=50) # one driver for one day.
sp.tail(1).plot(x="correctedLongitude",y="correctedLatitude",kind="scatter", label="end", ax=ax, marker="s", color="b",s=40) # one driver for one day.

stops.plot(ax=ax,markersize =50,color = "red",zorder=2, alpha=0.5, marker ="p") # plot the stops


ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")

ax.set_title("Sample trajectory with speed information")

plt.locator_params(axis='both', nbins=5)
plt.tight_layout()
plt.savefig("figures/trajectory.png", dpi=300) # save the figure

plt.savefig("figures/trajectory.pdf") # save the figure

# %%
fig, ax = plt.subplots(figsize=(8,3))

ax.plot(sp["datetime"],sp["speed"].rolling(6).mean(), color="0.3", linestyle="--") # lines styles: [":","-."]


ax.set_ylabel("speed (mph)")
ax.set_xlabel("time")
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

plt.tight_layout()
plt.savefig("figures/sample_speed.png", dpi=300)

# %%
sp.sort_values(by="datetime",inplace=True)
sp["acceleration"] = (sp["speed"].diff()/2.237)/sp["datetime"].diff().dt.total_seconds()

# %%
# viz the route, together with the stops and the trajectory

fig, ax = plt.subplots(figsize=(6*2,2.5*2))

sp.plot(x="correctedLongitude",y="correctedLatitude",kind="scatter",s=1.0, c="acceleration", cmap="RdYlGn", ax=ax) # one driver for one day.
sp.head(1).plot(x="correctedLongitude",y="correctedLatitude",kind="scatter", label="start", ax=ax, marker="o", color="r",s=50) # one driver for one day.
sp.tail(1).plot(x="correctedLongitude",y="correctedLatitude",kind="scatter", label="end", ax=ax, marker="s", color="b",s=40) # one driver for one day.

stops.plot(ax=ax,markersize =50,color = "red",zorder=2, alpha=0.5, marker ="p") # plot the stops


ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_title("Sample trajectory with acceleration information")

plt.locator_params(axis='both', nbins=5)
plt.tight_layout()
plt.savefig("figures/trajectory_acceleration.png", dpi=300) # save the figure

# %%
fig, ax = plt.subplots(figsize=(8,3))

ax.plot(sp["datetime"],sp["acceleration"], color="0.5", linestyle="-")

ax.set_xlabel("time")
ax.set_ylabel("acceleration ($m/s^2$)") 
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

plt.tight_layout()
plt.savefig("figures/sample_acceleration.png", dpi=300)

# %% [markdown]
# ### Calculate Energy Comsumption along the trajectory (todo)

# %%
# from get_consumption import get_traction_power

# %%
# load elevation related data

# long-lat range of the coverage area
maxlat,maxlon = 33.22934, -87.50141
minlat,minlon = 33.18679, -87.55292

# a matrix of elevation data
ele_mat = np.load("data/elevation_mat.npy")

# %%
ele_mat
# Out:
# array([[ 57,  57,  57, ..., 102, 102, 119],
#        [ 59,  58,  58, ..., 108, 108, 112],
#        [ 59,  58,  58, ..., 108, 108, 112],
#        ...,
#        [ 70,  66,  66, ...,  87,  87,  83],
#        [ 69,  73,  73, ...,  72,  72,  65],
#        [ 69,  73,  73, ...,  72,  72,  65]], dtype=int32)

# %%
# then take a look
plt.imshow(ele_mat[::-1],cmap="viridis",extent=[minlon,maxlon,minlat,maxlat])
plt.colorbar()
